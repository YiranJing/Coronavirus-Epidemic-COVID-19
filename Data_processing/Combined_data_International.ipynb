# %%
import pandas as pd
import csv
import glob
import os

# %%
path='~/Desktop/Coronavirus-Epidemic-2019-nCov/data/International'

# %%
extension='csv'

# %%
all_filenames=[i for i in glob.glob('*.{}'.format(extension))]

# %%
combined_csv=pd.concat([pd.read_csv(f) for f in all_filenames],ignore_index=True)
# Out:
#       地区  2020-01-20  2020-01-21  2020-01-22  2020-01-23  2020-01-24  \
# 0     上海           2           9           9          20          20
# 1   中国台湾           0           0           1           1           3
# 2   中国澳门           0           0           1           2           2
# 3   中国香港           0           0           1           2           5
# 4     云南           0           1           1           2           5
# 5    内蒙古           0           0           0           0           1
# 6     北京           5          10          14          26          36
# 7     吉林           0           0           0           1           4
# 8     四川           0           2           5           8          15
# 9     天津           0           2           4           5           8
# 10    宁夏           0           0           1           1           3
# 11    安徽           0           0           1          15          39
# 12    山东           0           1           2           6          21
# 13    山西           0           0           1           1           6
# 14    广东          14          26          26          53          78
# 15    广西           0           0           2          13          23
# 16    新疆           0           0           0           2           3
# 17    江苏           0           0           1           5          18
# 18    江西           0           2           2           7          18
# 19    河北           0           0           1           2           8
# 20    河南           0           1           5           5          32
# 21    浙江           0           5          10          27          62
# 22    海南           0           0           4           5           8
# 23    湖北         270         375         444         583         729
# 24    湖南           0           1           4           9          43
# 25    甘肃           0           0           0           2           4
# 26    福建           0           0           1           5          10
# 27    贵州           0           0           1           3           4
# 28    辽宁           0           0           2           3          12
# 29    重庆           0           5           6           9          57
# 30    陕西           0           0           0           3           5
# 31    青海           0           0           0           0           0
# 32   黑龙江           0           0           0           4           9
#
#     2020-01-25  2020-01-26
# 0           40          53
# 1            3           4
# 2            5           6
# 3            5           8
# 4           11          19
# 5            7          11
# 6           54          68
# 7            4           6
# 8           44          69
# 9           13          14
# 10           4           4
# 11          60          70
# 12          46          63
# 13           9          13
# 14         111         146
# 15          36          46
# 16           4           5
# 17          31          47
# 18          36          48
# 19          13          18
# 20          83         128
# 21         104         128
# 22          22          22
# 23        1052        1423
# 24          69         100
# 25           7          14
# 26          29          35
# 27           5           7
# 28          21          22
# 29          75         110
# 30          22          22
# 31           1           4
# 32          15          21

# %%
combined_csv=combined_csv.sort_values(by=['地区','时间'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-ac4654b4785a> in <module>
# ----> 1 combined_csv=combined_csv.sort_values(by=['地区','时间'])
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    4709
#    4710             keys = [self._get_label_or_level_values(x, axis=axis)
# -> 4711                     for x in by]
#    4712             indexer = lexsort_indexer(keys, orders=ascending,
#    4713                                       na_position=na_position)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in <listcomp>(.0)
#    4709
#    4710             keys = [self._get_label_or_level_values(x, axis=axis)
# -> 4711                     for x in by]
#    4712             indexer = lexsort_indexer(keys, orders=ascending,
#    4713                                       na_position=na_position)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1704             values = self.axes[axis].get_level_values(key)._values
#    1705         else:
# -> 1706             raise KeyError(key)
#    1707
#    1708         # Check for duplicates
#
# KeyError: '时间'

# %%
combined=combined_csv.pivot(index='地区',columns='时间',values='确诊')

# %%
combined_data=combined.to_csv('~/Desktop/Coronavirus-Epidemic-2019-nCov/data/Merge_China/combined_data.csv',header=True)
