# %%
import pandas as pd
import numpy as np
import operator
import matplotlib.pyplot as plt
import pandas as pd
import pandas
from metadata import *
import datetime
import matplotlib.dates as mdates
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import PolynomialFeatures
import warnings
warnings.filterwarnings('ignore')

# %%
# %%time
## Update data from DXY
! cd ../data_processing && python DXY_AreaData_query.py

## Load data 
df = pd.read_csv("../data/DXYArea.csv")
"""
Data Cleaning 
"""
df = df[df['date'] != df['date'].max()] # remove todays' records (since it can be incompleted)
# Out:
# 2020-02-10 21:54:44Update records successfully to ../data/DXY_Chinese.csv
# Save area daily dataset (English) into ../data/DXYArea.csv
# CPU times: user 128 ms, sys: 43.2 ms, total: 172 ms
# Wall time: 8.92 s

# %% [markdown]
# ## Cities which has decreased confirmed cases
#
# The records seems correct after Feb.

# %%
test_confirm_monotone_increase(df)
